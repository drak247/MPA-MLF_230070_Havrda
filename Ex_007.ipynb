# %% [markdown]
# <a href="https://colab.research.google.com/github/drak247/MPA-MLF_230070_Havrda/blob/main/Ex_007.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # MKA-MLF, Lab_07 Convolutional Neural Networks

# %% [markdown]
# ## Exercise - Hand-written digits recognition

# %% [markdown]
# Create CNN which will process and recognize handwritten digits. For this purposes please use the MNIST database (Modified National Institute of Standards and Technology database) which is a large database of handwritten digits that is commonly used for training various image processing systems.
#
# The datasample of the MNIST datasets can be see in the following picture

# %% [markdown]
# ![mnist_data_sample.png](attachment:eb3e0d6a-ccb0-499d-9847-ecbc554dbce0.png)

# %% [markdown]
# ### Task description

# %% [markdown]
# In the terms of machine learning, the Hand-written digits recognition can be threated as a multi-class classification problem. This is very important knowledge to structure our model in the correct way (Especially the output-layer, including the number of neurons and activations function and the overall loss function and classification metrics)

# %% [markdown]
# ### 0. Import libraries

# %% [markdown]
# Import the all necessary libraries, you can get inspired by the previous exercises. You can improst the libraries gradually, when do you progressing with the task

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.datasets import mnist
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
###################################
# Write your own code here #



###################################
font = {'weight' : 'bold',
        'size'   : 12}

matplotlib.rc('font', **font)

# %% [markdown]
# ### 1. Dataset

# %% [markdown]
# #### 1.1 Load Dataset

# %% [markdown]
# You can load the dataset using the following code

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# #### 1.2 Dataset examination

# %% [markdown]
# Using the following code, display random images,

# %%
def display_random_images(x_data: np.array, y_data: np.array, count: int = 10) -> None:
  index = np.array(len(x_data))
  selected_ind = np.random.choice(index, count)

  selected_img = x_data[selected_ind]
  selected_labels = y_data[selected_ind]
  concat_img = np.concatenate(selected_img, axis=1)

  plt.figure(figsize=(20,10))
  plt.imshow(concat_img, cmap="gray")

  for id_label, label in enumerate(selected_labels):
    plt.text(14 + 28*id_label, 28*(5/4), label)
  plt.axis('off')
  plt.show()

# %%
display_random_images(X_train, y_train)

# %% [markdown]
# Examine the dataset. Answer for yourself the following questions:
#
# - What kind of data occurs in our dataset?
# - How many data samples do we have in train and test datasets?
# - How many colour channels does the input variable have?
# - What is the size of the input images?
# - What is the necessary preprocessing of the input data X?
# - How many classes do we have in target varoable?
# - What is the necessary preprocessing of target variable y?

# %% [markdown]
# #### 1.3 Dataset preprocessing

# %% [markdown]
# Perform the necessary data preprocessing. The best way to preprocess the data would be one hot encoding for the target variable and normalization for the input variable (using min-max or z-score normalization)

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Reshape data to add a channel dimension (for grayscale images, this is 1)
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)

num_classes = 10  # MNIST has 10 classes (digits 0-9)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (60000, 28, 28, 1)
# y_train shape: (60000, 10)
# X_test shape: (10000, 28, 28, 1)
# y_test shape: (10000, 10)

# %% [markdown]
# ### 2. Build the model

# %% [markdown]
# In this section, your task will be to define the model architecture. The intial structure can be defined as follows:
#
# Input_layer -> Convolutional_layer(kernel_size=(3,3), no_channels=32) -> Maxpooling_layer(kernel_size=(2, 2)) -> Flatten_layer -> Dense_layer (num_classes)

# %% [markdown]
# #### 2.1 Define the model structure

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, LeakyReLU, BatchNormalization
from keras.models import Sequential
from keras.regularizers import l2

weight_decay = 1e-4

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),kernel_regularizer=l2(weight_decay), input_shape=(28, 28, 1)))
#model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(28, 28, 1)))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, kernel_size=(3, 3),kernel_regularizer=l2(weight_decay), input_shape=(28, 28, 1)))
model.add(BatchNormalization())
#model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(28, 28, 1)))
model.add(LeakyReLU(alpha=0.1))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %% [markdown]
# #### 2.2 Compile the model

# %% [markdown]
# Build the model, use the relevant metrics, optimizer and loss function. While choosing the metrics and loss function, consider fact that we are are trying to solve the multiclass classification problem

# %%
from keras.optimizers import SGD
loss = 'categorical_crossentropy'
optimizer = SGD(learning_rate=0.001)
metrics = ['accuracy']

###################################
# Write your own code here #
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

###################################
model.summary()
# Out:
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_26 (Conv2D)              │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 26, 26, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_26 (LeakyReLU)      │ (None, 26, 26, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_26 (MaxPooling2D) │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_27 (Conv2D)              │ (None, 11, 11, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 11, 11, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_27 (LeakyReLU)      │ (None, 11, 11, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_27 (MaxPooling2D) │ (None, 5, 5, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_18 (Flatten)            │ (None, 800)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 10)             │         8,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,834 (69.66 KB)
#  Trainable params: 17,706 (69.16 KB)
#  Non-trainable params: 128 (512.00 B)

# %% [markdown]
# ### 3. Training stage

# %% [markdown]
# #### 3.1 Model training

# %% [markdown]
# train your model, define the relevant hyperparameters (no. epochs, batch_size), use 20p of the training data for validation

# %%
###################################
# Write your own code here #
from keras.callbacks import EarlyStopping
# Define Early Stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the improved model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, callbacks=[early_stopping])


###################################
# Out:
# Epoch 1/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8301 - loss: 0.6487 - val_accuracy: 0.9287 - val_loss: 0.2982
# Epoch 2/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9310 - loss: 0.2670 - val_accuracy: 0.9490 - val_loss: 0.2062
# Epoch 3/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9476 - loss: 0.1996 - val_accuracy: 0.9583 - val_loss: 0.1675
# Epoch 4/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9561 - loss: 0.1655 - val_accuracy: 0.9643 - val_loss: 0.1443
# Epoch 5/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9615 - loss: 0.1452 - val_accuracy: 0.9683 - val_loss: 0.1288
# Epoch 6/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9652 - loss: 0.1307 - val_accuracy: 0.9706 - val_loss: 0.1188
# Epoch 7/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9685 - loss: 0.1194 - val_accuracy: 0.9718 - val_loss: 0.1108
# Epoch 8/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9707 - loss: 0.1109 - val_accuracy: 0.9743 - val_loss: 0.1047
# Epoch 9/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9720 - loss: 0.1040 - val_accuracy: 0.9748 - val_loss: 0.0993
# Epoch 10/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9738 - loss: 0.0984 - val_accuracy: 0.9756 - val_loss: 0.0954
# Epoch 11/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9746 - loss: 0.0936 - val_accuracy: 0.9762 - val_loss: 0.0923
# Epoch 12/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9759 - loss: 0.0897 - val_accuracy: 0.9769 - val_loss: 0.0888
# Epoch 13/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9775 - loss: 0.0855 - val_accuracy: 0.9771 - val_loss: 0.0866
# Epoch 14/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9779 - loss: 0.0828 - val_accuracy: 0.9778 - val_loss: 0.0835
# Epoch 15/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9785 - loss: 0.0798 - val_accuracy: 0.9776 - val_loss: 0.0823
# Epoch 16/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9797 - loss: 0.0771 - val_accuracy: 0.9788 - val_loss: 0.0803
# Epoch 17/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9798 - loss: 0.0748 - val_accuracy: 0.9787 - val_loss: 0.0788
# Epoch 18/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9807 - loss: 0.0727 - val_accuracy: 0.9791 - val_loss: 0.0771
# Epoch 19/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9809 - loss: 0.0712 - val_accuracy: 0.9797 - val_loss: 0.0750
# Epoch 20/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9816 - loss: 0.0688 - val_accuracy: 0.9802 - val_loss: 0.0746
# Epoch 21/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9824 - loss: 0.0676 - val_accuracy: 0.9809 - val_loss: 0.0727
# Epoch 22/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9826 - loss: 0.0657 - val_accuracy: 0.9810 - val_loss: 0.0712
# Epoch 23/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9833 - loss: 0.0640 - val_accuracy: 0.9802 - val_loss: 0.0712
# Epoch 24/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9837 - loss: 0.0625 - val_accuracy: 0.9810 - val_loss: 0.0699
# Epoch 25/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9837 - loss: 0.0612 - val_accuracy: 0.9815 - val_loss: 0.0684
# Epoch 26/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.
100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9905 - loss: 0.0386 - val_accuracy: 0.9845 - val_loss: 0.0560
# Epoch 58/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9904 - loss: 0.0384 - val_accuracy: 0.9848 - val_loss: 0.0553
# Epoch 59/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9904 - loss: 0.0377 - val_accuracy: 0.9849 - val_loss: 0.0550
# Epoch 60/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9909 - loss: 0.0372 - val_accuracy: 0.9846 - val_loss: 0.0554
# Epoch 61/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9911 - loss: 0.0369 - val_accuracy: 0.9847 - val_loss: 0.0546
# Epoch 62/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9914 - loss: 0.0368 - val_accuracy: 0.9853 - val_loss: 0.0543
# Epoch 63/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9907 - loss: 0.0365 - val_accuracy: 0.9852 - val_loss: 0.0547
# Epoch 64/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9913 - loss: 0.0361 - val_accuracy: 0.9847 - val_loss: 0.0551
# Epoch 65/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9915 - loss: 0.0358 - val_accuracy: 0.9850 - val_loss: 0.0541
# Epoch 66/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9912 - loss: 0.0355 - val_accuracy: 0.9849 - val_loss: 0.0548
# Epoch 67/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9916 - loss: 0.0354 - val_accuracy: 0.9847 - val_loss: 0.0545
# Epoch 68/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9914 - loss: 0.0348 - val_accuracy: 0.9852 - val_loss: 0.0531
# Epoch 69/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9917 - loss: 0.0342 - val_accuracy: 0.9852 - val_loss: 0.0531
# Epoch 70/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9916 - loss: 0.0341 - val_accuracy: 0.9852 - val_loss: 0.0537
# Epoch 71/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9921 - loss: 0.0335 - val_accuracy: 0.9852 - val_loss: 0.0546
# Epoch 72/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9922 - loss: 0.0333 - val_accuracy: 0.9856 - val_loss: 0.0540
# Epoch 73/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9921 - loss: 0.0331 - val_accuracy: 0.9852 - val_loss: 0.0533

# %% [markdown]
# #### 3.1 Model Evaluation on validation data

# %% [markdown]
# Plot the development of the training and validation loss, and training and validation metrics.

# %%
###################################
# Write your own code here #
score = model.evaluate(X_test, y_test, verbose=0)
print('Leaky ReLU Model Test loss:', score[0])
print(f'Leaky ReLU Model Test accuracy: {score[1]*100} %')

# Plotting training history for improved model
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Leaky ReLU Model Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Leaky ReLU Model Accuracy History')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()


###################################
# Out:
# Leaky ReLU Model Test loss: 0.04168229550123215
# Leaky ReLU Model Test accuracy: 98.8099992275238 %

# %% [markdown]
# ### 4. Model evaluation

# %% [markdown]
# Evaluate the model on the testing dataset using the relevant metrics. Use the confusion metrics as the one of the metrics.

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Evaluate the model on the test data
score = model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss: {score[0]:.4f}')
print(f'Test accuracy: {score[1]*100:.2f}%')

# Predict the values from the test dataset
y_pred = model.predict(X_test)

# Convert predictions classes to one hot vectors
y_pred_classes = np.argmax(y_pred, axis=1)
# Convert test data to one hot vectors
y_true = np.argmax(y_test, axis=1)

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes))
# Out:
# Test loss: 0.0417
# Test accuracy: 98.81%
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       980
#            1       0.99      1.00      0.99      1135
#            2       0.99      0.98      0.99      1032
#            3       0.99      0.99      0.99      1010
#            4       0.99      0.99      0.99       982
#            5       0.99      0.99      0.99       892
#            6       1.00      0.99      0.99       958
#            7       0.98      0.99      0.98      1028
#            8       0.99      0.99      0.99       974
#            9       0.99      0.97      0.98      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %% [markdown]
# ### 5. Hyperparameter tunning and regularization techniques

# %% [markdown]
# When your code is ready and fully functional, try several changes in the hyperparameters and see how they influence the testing metrics. Try changes in the network structure. You can also try adding regularization techniques such as L1, L2, and Dropout. Based on the development of training and validation loss, try to identify overfitting and avoid it
